# %% [markdown]
# <a href="https://colab.research.google.com/github/kaikai23/Covid19-Group15-BigDataAnalytics/blob/main/Covid_19Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Loading the Covid-19 Dataset:**

# %%
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent  ... life_expectancy human_development_index
# 0      AFG      Asia  ...           64.83                   0.511
# 1      AFG      Asia  ...           64.83                   0.511
# 2      AFG      Asia  ...           64.83                   0.511
# 3      AFG      Asia  ...           64.83                   0.511
# 4      AFG      Asia  ...           64.83                   0.511
#
# [5 rows x 59 columns]

# %% [markdown]
# # **Data Processng/Cleaning**

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# # **Model building**

# %% [markdown]
# # **Visualization and Report Findings**

# %% [markdown]
# **Number of valid values for each field(column):**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93740 entries, 0 to 93739
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               93740 non-null  object
#  1   continent                              89305 non-null  object
#  2   location                               93740 non-null  object
#  3   date                                   93740 non-null  object
#  4   total_cases                            90755 non-null  float64
#  5   new_cases                              90754 non-null  float64
#  6   new_cases_smoothed                     89742 non-null  float64
#  7   total_deaths                           80800 non-null  float64
#  8   new_deaths                             80958 non-null  float64
#  9   new_deaths_smoothed                    89742 non-null  float64
#  10  total_cases_per_million                90270 non-null  float64
#  11  new_cases_per_million                  90269 non-null  float64
#  12  new_cases_smoothed_per_million         89262 non-null  float64
#  13  total_deaths_per_million               80328 non-null  float64
#  14  new_deaths_per_million                 80486 non-null  float64
#  15  new_deaths_smoothed_per_million        89262 non-null  float64
#  16  reproduction_rate                      75391 non-null  float64
#  17  icu_patients                           9506 non-null   float64
#  18  icu_patients_per_million               9506 non-null   float64
#  19  hosp_patients                          11803 non-null  float64
#  20  hosp_patients_per_million              11803 non-null  float64
#  21  weekly_icu_admissions                  861 non-null    float64
#  22  weekly_icu_admissions_per_million      861 non-null    float64
#  23  weekly_hosp_admissions                 1499 non-null   float64
#  24  weekly_hosp_admissions_per_million     1499 non-null   float64
#  25  new_tests                              42244 non-null  float64
#  26  total_tests                            41934 non-null  float64
#  27  total_tests_per_thousand               41934 non-null  float64
#  28  new_tests_per_thousand                 42244 non-null  float64
#  29  new_tests_smoothed                     48953 non-null  float64
#  30  new_tests_smoothed_per_thousand        48953 non-null  float64
#  31  positive_rate                          46132 non-null  float64
#  32  tests_per_case                         45533 non-null  float64
#  33  tests_units                            50540 non-null  object
#  34  total_vaccinations                     13514 non-null  float64
#  35  people_vaccinated                      12734 non-null  float64
#  36  people_fully_vaccinated                10004 non-null  float64
#  37  new_vaccinations                       11332 non-null  float64
#  38  new_vaccinations_smoothed              22967 non-null  float64
#  39  total_vaccinations_per_hundred         13514 non-null  float64
#  40  people_vaccinated_per_hundred          12734 non-null  float64
#  41  people_fully_vaccinated_per_hundred    10004 non-null  float64
#  42  new_vaccinations_smoothed_per_million  22967 non-null  float64
#  43  stringency_index                       78978 non-null  float64
#  44  population                             93121 non-null  float64
#  45  population_density                     87167 non-null  float64
#  46  median_age                             84061 non-null  float64
#  47  aged_65_older                          83113 non-null  float64
#  48  aged_70_older                          83595 non-null  float64
#  49  gdp_per_capita                         84323 non-null  float64
#  50  extreme_poverty                        57027 non-null  float64
#  51  cardiovasc_death_rate                  84460 non-null  float64
#  52  diabetes_prevalence                    86461 non-null  float64
#  53  female_smokers                         66103 non-null  float64
#  54  male_smokers                           65134 non-null  float64
#  55  handwashing_facilities                 42428 non-null  float64
#  56  hospital_beds_per_thousand             76987 non-null  float64
#  57  life_expectancy                        89013 non-null  float64
#  58  human_development_index                84632 non-null  float64
# dtypes: float64(54), object(5)
# memory usage: 42.2+ MB

# %% [markdown]
# **Statistics of this dataset:**

# %%
df.describe()
# Out:
#         total_cases     new_cases  ...  life_expectancy  human_development_index
# count  9.075500e+04  9.075400e+04  ...     89013.000000             84632.000000
# mean   9.626804e+05  6.074791e+03  ...        73.233876                 0.727675
# std    6.637316e+06  3.861324e+04  ...         7.560899                 0.150396
# min    1.000000e+00 -3.486670e+05  ...        53.280000                 0.394000
# 25%    1.114000e+03  2.000000e+00  ...        67.920000                 0.602000
# 50%    1.231200e+04  7.200000e+01  ...        74.620000                 0.748000
# 75%    1.298900e+05  7.930000e+02  ...        78.740000                 0.848000
# max    1.729871e+08  1.498126e+06  ...        86.750000                 0.957000
#
# [8 rows x 54 columns]

# %%
df.hist(bins=20, figsize=(30,30))
plt.show()

# %% [markdown]
# **Number of records for each location:**

# %%
iso_dic={}
for i in range(len(df)):
  if df['location'][i] in iso_dic: iso_dic[df['location'][i]]=iso_dic[df['location'][i]]+1
  else: iso_dic[df['location'][i]]=1
iso_dic
# Out:
# {'Afghanistan': 468,
#  'Africa': 479,
#  'Albania': 467,
#  'Algeria': 467,
#  'Andorra': 461,
#  'Angola': 443,
#  'Anguilla': 114,
#  'Antigua and Barbuda': 450,
#  'Argentina': 522,
#  'Armenia': 462,
#  'Aruba': 68,
#  'Asia': 501,
#  'Australia': 497,
#  'Austria': 467,
#  'Azerbaijan': 462,
#  'Bahamas': 447,
#  'Bahrain': 468,
#  'Bangladesh': 460,
#  'Barbados': 446,
#  'Belarus': 464,
#  'Belgium': 488,
#  'Belize': 440,
#  'Benin': 447,
#  'Bermuda': 142,
#  'Bhutan': 457,
#  'Bolivia': 452,
#  'Bonaire Sint Eustatius and Saba': 1,
#  'Bosnia and Herzegovina': 458,
#  'Botswana': 433,
#  'Brazil': 466,
#  'British Virgin Islands': 8,
#  'Brunei': 454,
#  'Bulgaria': 455,
#  'Burkina Faso': 453,
#  'Burundi': 432,
#  'Cambodia': 496,
#  'Cameroon': 457,
#  'Canada': 497,
#  'Cape Verde': 443,
#  'Cayman Islands': 162,
#  'Central African Republic': 448,
#  'Chad': 444,
#  'Chile': 469,
#  'China': 501,
#  'Colombia': 457,
#  'Comoros': 402,
#  'Congo': 448,
#  'Cook Islands': 8,
#  'Costa Rica': 457,
#  "Cote d'Ivoire": 452,
#  'Croatia': 467,
#  'Cuba': 451,
#  'Curacao': 69,
#  'Cyprus': 456,
#  'Czechia': 462,
#  'Democratic Republic of Congo': 452,
#  'Denmark': 490,
#  'Djibouti': 445,
#  'Dominica': 441,
#  'Dominican Republic': 462,
#  'Ecuador': 462,
#  'Egypt': 478,
#  'El Salvador': 444,
#  'Equatorial Guinea': 448,
#  'Eritrea': 442,
#  'Estonia': 489,
#  'Eswatini': 449,
#  'Ethiopia': 450,
#  'Europe': 500,
#  'European Union': 500,
#  'Faeroe Islands': 127,
#  'Falkland Islands': 67,
#  'Fiji': 493,
#  'Finland': 494,
#  'France': 499,
#  'French Polynesia': 120,
#  'Gabon': 449,
#  'Gambia': 446,
#  'Georgia': 466,
#  'Germany': 499,
#  'Ghana': 449,
#  'Gibraltar': 144,
#  'Greece': 466,
#  'Greenland': 129,
#  'Grenada': 441,
#  'Guatemala': 475,
#  'Guernsey': 132,
#  'Guinea': 450,
#  'Guinea-Bissau': 438,
#  'Guyana': 451,
#  'Haiti': 443,
#  'Honduras': 452,
#  'Hong Kong': 500,
#  'Hungary': 460,
#  'Iceland': 465,
#  'India': 493,
#  'Indonesia': 461,
#  'International': 485,
#  'Iran': 473,
#  'Iraq': 468,
#  'Ireland': 470,
#  'Isle of Man': 134,
#  'Israel': 473,
#  'Italy': 492,
#  'Jamaica': 452,
#  'Japan': 501,
#  'Jersey': 78,
#  'Jordan': 460,
#  'Kazakhstan': 450,
#  'Kenya': 457,
#  'Kiribati': 19,
#  'Kosovo': 449,
#  'Kuwait': 468,
#  'Kyrgyzstan': 445,
#  'Laos': 439,
#  'Latvia': 470,
#  'Lebanon': 471,
#  'Lesotho': 389,
#  'Liberia': 447,
#  'Libya': 459,
#  'Liechtenstein': 459,
#  'Lithuania': 463,
#  'Luxembourg': 468,
#  'Macao': 118,
#  'Madagascar': 443,
#  'Malawi': 434,
#  'Malaysia': 498,
#  'Maldives': 455,
#  'Mali': 438,
#  'Malta': 486,
#  'Marshall Islands': 221,
#  'Mauritania': 449,
#  'Mauritius': 445,
#  'Mexico': 522,
#  'Micronesia (country)': 136,
#  'Moldova': 455,
#  'Monaco': 463,
#  'Mongolia': 453,
#  'Montenegro': 446,
#  'Montserrat': 110,
#  'Morocco': 485,
#  'Mozambique': 441,
#  'Myanmar': 436,
#  'Namibia': 449,
#  'Nauru': 41,
#  'Nepal': 498,
#  'Netherlands': 465,
#  'New Caledonia': 120,
#  'New Zealand': 464,
#  'Nicaragua': 444,
#  'Niger': 443,
#  'Nigeria': 464,
#  'North America': 501,
#  'North Macedonia': 466,
#  'Northern Cyprus': 134,
#  'Norway': 467,
#  'Oceania': 498,
#  'Oman': 468,
#  'Pakistan': 467,
#  'Palestine': 458,
#  'Panama': 454,
#  'Papua New Guinea': 443,
#  'Paraguay': 456,
#  'Peru': 517,
#  'Philippines': 493,
#  'Poland': 459,
#  'Portugal': 469,
#  'Qatar': 463,
#  'Romania': 466,
#  'Russia': 492,
#  'Rwanda': 449,
#  'Saint Helena': 92,
#  'Saint Kitts and Nevis': 438,
#  'Saint Lucia': 449,
#  'Saint Vincent and the Grenadines': 449,
#  'Samoa': 200,
#  'San Marino': 465,
#  'Sao Tome and Principe': 426,
#  'Saudi Arabia': 461,
#  'Senegal': 464,
#  'Serbia': 466,
#  'Seychelles': 449,
#  'Sierra Leone': 432,
#  'Singapore': 500,
#  'Sint Maarten (Dutch part)': 22,
#  'Slovakia': 457,
#  'Slovenia': 490,
#  'Solomon Islands': 237,
#  'Somalia': 447,
#  'South Africa': 485,
#  'South America': 470,
#  'South Korea': 502,
#  'South Sudan': 427,
#  'Spain': 491,
#  'Sri Lanka': 496,
#  'Sudan': 451,
#  'Suriname': 449,
#  'Sweden': 491,
#  'Switzerland': 467,
#  'Syria': 441,
#  'Taiwan': 507,
#  'Tajikistan': 402,
#  'Tanzania': 447,
#  'Thailand': 519,
#  'Timor': 441,
#  'Togo': 459,
#  'Tonga': 43,
#  'Trinidad and Tobago': 449,
#  'Tunisia': 459,
#  'Turkey': 452,
#  'Turkmenistan': 1,
#  'Turks and Caicos Islands': 139,
#  'Tuvalu': 36,
#  'Uganda': 442,
#  'Ukraine': 460,
#  'United Arab Emirates': 494,
#  'United Kingdom': 493,
#  'United States': 502,
#  'Uruguay': 450,
#  'Uzbekistan': 448,
#  'Vanuatu': 208,
#  'Vatican': 457,
#  'Venezuela': 449,
#  'Vietnam': 500,
#  'Wallis and Futuna': 71,
#  'World': 501,
#  'Yemen': 422,
#  'Zambia': 445,
#  'Zimbabwe': 443}

# %% [markdown]
# **The list of countries(and number of days recorded) where the highest infection rates ever exceeded 10%:**

# %%
countries={}
for i in range(len(df)):
  if df['total_cases_per_million'][i]>100000 and df['location'][i] not in countries:
    countries[df['location'][i]]=len(df[df['location']==df['location'][i]])
print(countries)
# Out:
# {'Andorra': 461, 'Bahrain': 468, 'Czechia': 462, 'Lithuania': 463, 'Luxembourg': 468, 'Maldives': 455, 'Montenegro': 446, 'San Marino': 465, 'Serbia': 466, 'Seychelles': 449, 'Slovenia': 490, 'Sweden': 491, 'United States': 502}

# %% [markdown]
# **A concrete case study: United States**

# %%
df_us=df[df['location']=='United States']
len(df_us)
# Out:
# 502

# %%
plt.plot(df_us['date'],df_us['total_cases'])
plt.xlabel('Dates from 2020.Feb to 2021.June')
plt.ylabel('Total infected people')
plt.xticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)

# %%
plt.plot(df_us['date'],df_us['new_cases'])
plt.xlabel('Dates from 2020.Feb to 2021.June')
plt.ylabel('New Cases per day')
plt.xticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)
